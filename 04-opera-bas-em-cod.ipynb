# %% [markdown]
# ## Operações Básicas em Código
#
# ### Sobre a Matemática
#
# As 4 (quatro) operações básicas da matemática são: adição, subtração, multiplicação e divisão.
#
# A soma (ou adição) é a operação matemática que corresponde às ideias de juntar quantidades ou acrescentar uma quantidade a outra. A sentença 2 + 3 = 5 indica uma adição cuja parcelas são 2 e 3 e cujo resultado ou soma é 5.
#
# A subtração é a operação matemática associada às ideias de tirar uma quantidade de outra, verificar quanto falta em uma quantidade para chegar a outra, encontrar a diferença entre duas quantidades. A sentença 10 – 7 = 3 representa uma subtração. O resultado 3 chama-se diferença.
#
# A multiplicação é a operação matemática que combina dois valores (os “fatores”) para obter um resultado chamado produto.
#
# A divisão é a operação matemática que corresponde às ideias de repartir uma quantidade em partes iguais ou de verificar quantas vezes uma quantidade cabe em outra. Os termos de uma divisão são: dividendo, divisor, quociente e resto. O resto deve sempre ser menor que o divisor.

# %% [markdown]
# ### Sobre o Código
#
# Na linguagem de Programação Python,
#
# float – é a função usada para converter em número de ponto flutuante (decimais).
#
# input – é a função utilizada para receber dados do usuário. O input sempre retorna uma string, ou seja, o tipo de dado srt (texto). Por isso, utilizamos float para converte-lo e realizarmos operações.
#
# +, -, *. / – são os operadores aritméticos que realizam a soma, a subtração, a multiplicação e a divisão.
#
# if… else – é uma estrutura condicional, usada para tomar decisões no código. Nela é permitido que o programa execute um bloco de comandos se uma condição for verdadeira (if), e outro bloco alternativo (else) caso a condição seja falsa.
#
# print – é a função utilizada para exibir mensagens na tela.
#
# '#' – é o caractere usado para comentar o código, não sendo executado pelo interpretador Python.
#
# Vamos ao código…

# %%
# Programa que lê dois números e mostra as operações básicas

# Entrada de dados
num1 = float(input("Digite o primeiro número: "))
num2 = float(input("Digite o segundo número: "))

# Operações
soma = num1 + num2
subtracao = num1 - num2
multiplicacao = num1 * num2

# Tratando divisão por zero
if num2 != 0:
    divisao = num1 / num2
else:
    divisao = "Não é possível dividir por zero."

# Saída
print(f"\nResultados:")
print(f"Soma: {soma}")
print(f"Subtração: {subtracao}")
print(f"Multiplicação: {multiplicacao}")
print(f"Divisão: {divisao}")

# %% [markdown]
# Fonte:
#
# Código gerado por ChatGPT com revisão humana.
#
# https://docs.python.org/pt-br/3/ (Documentação Oficial do Python)
